# %% [markdown]
# # 1

# %%
# !pip install yfinance
! pip install "notebook>=5.3" "ipywidgets>=7.2"

# %%
import yfinance as yf
import pandas as pd
import plotly.graph_objects as go

print("imported")
# Out:
# imported

# %%
tata=yf.Ticker("TATASTEEL.NS")

# %%
tata_info=tata.info
tata_info
# Out:
# {'zip': '400001',
#  'sector': 'Basic Materials',
#  'fullTimeEmployees': 65000,
# ...

# %%
tata_info['country']
# Out:
# 'India'

# %%
tata_info['sector']
# Out:
# 'Basic Materials'

# %%
tata_share_data_price=tata.history(period="max")

# %%
tata_share_data_price.head()
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 1996-01-01  58.996066  59.218413  58.269734  59.070183  1024222        0.0
# 1996-01-02  58.996071  59.218419  57.825043  57.973278  1695431        0.0
# 1996-01-03  57.973285  59.292543  57.825050  57.988106  1351411        0.0
# 1996-01-04  57.069058  57.069058  54.845587  56.150024  3478582        0.0
# 1996-01-05  55.468159  55.734974  54.475008  55.038288  3013803        0.0
#
#             Stock Splits
# Date
# 1996-01-01           0.0
# 1996-01-02           0.0
# 1996-01-03           0.0
# 1996-01-04           0.0
# 1996-01-05           0.0

# %%
tata_share_data_price.reset_index(inplace=True)

# %%
tata_share_data_price.plot(x="Date",y="Open",title="Tata Steel Stocks Open Prices")
# Out:
# <AxesSubplot:title={'center':'Tata Steel Stocks Open Prices'}, xlabel='Date'>

# %%
tata_share_data_price.plot(x="Date",y="Open",title="Tata Steel Stock Close Prices")
# Out:
# <AxesSubplot:title={'center':'Tata Steel Stock Close Prices'}, xlabel='Date'>

# %% [markdown]
# ### Dividends
#
# Dividends are the distribution of a companys profits to shareholders. In this case they are defined as an amount of money returned per share an investor owns. Using the variable dividends we can get a dataframe of the data. The period of the data is given by the period defined in the 'history` function.

# %%
tata.dividends
# Out:
# Date
# 1999-05-13     2.245800
# 2000-04-06     2.245800
# 2001-05-24     2.807250
# 2002-05-28     2.245800
# 2003-06-09     4.491600
# 2004-06-08     5.614500
# 2005-06-07    10.948276
# 2006-05-26    10.948276
# 2007-06-08    13.053713
# 2008-07-18    15.243786
# 2009-07-06    15.243786
# 2010-07-12     7.621893
# 2011-07-04    11.432840
# 2012-07-16    11.432840
# 2013-07-15     7.621893
# 2014-07-14     9.527366
# 2015-07-23     7.621893
# 2016-07-28     7.621893
# 2017-07-20     9.527366
# 2018-07-05    10.000000
# 2019-07-04    13.000000
# 2020-08-06    10.000000
# Name: Dividends, dtype: float64

# %%
tata.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tata_share_data_price['Volume']
# Out:
# 0        1024222
# 1        1695431
# 2        1351411
# 3        3478582
# 4        3013803
#           ...
# 6339    28044585
# 6340    36842098
# 6341    30575986
# 6342    20778920
# 6343    17108888
# Name: Volume, Length: 6344, dtype: int64

# %%
tata_share_data_price.plot(x='Date',y='Volume')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tata_share_data_price['Close']
# Out:
# 0        59.070183
# 1        57.973278
# 2        57.988106
# 3        56.150024
# 4        55.038288
#            ...
# 6339    811.849976
# 6340    863.049988
# 6341    867.750000
# 6342    862.849976
# 6343    874.849976
# Name: Close, Length: 6344, dtype: float64

# %% [markdown]
# # 2

# %%
tata.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1999-05-13   2.245800           0.0
# 2000-04-06   2.245800           0.0
# 2001-05-24   2.807250           0.0
# 2002-05-28   2.245800           0.0
# 2003-06-09   4.491600           0.0
# 2004-06-08   5.614500           0.0
# 2004-08-11   0.000000           1.5
# 2005-06-07  10.948276           0.0
# 2006-05-26  10.948276           0.0
# 2007-06-08  13.053713           0.0
# 2008-07-18  15.243786           0.0
# 2009-07-06  15.243786           0.0
# 2010-07-12   7.621893           0.0
# 2011-07-04  11.432840           0.0
# 2012-07-16  11.432840           0.0
# 2013-07-15   7.621893           0.0
# 2014-07-14   9.527366           0.0
# 2015-07-23   7.621893           0.0
# 2016-07-28   7.621893           0.0
# 2017-07-20   9.527366           0.0
# 2018-07-05  10.000000           0.0
# 2019-07-04  13.000000           0.0
# 2020-08-06  10.000000           0.0

# %%
tata.sustainability
# Out:
#                           Value
# 2021-3
# palmOil                   False
# controversialWeapons      False
# gambling                  False
# socialScore               14.37
# nuclear                   False
# furLeather                False
# alcoholic                 False
# gmo                       False
# catholic                  False
# socialPercentile           None
# peerCount                    24
# governanceScore            8.84
# environmentPercentile      None
# animalTesting             False
# tobacco                   False
# totalEsg                  39.53
# highestControversy            3
# esgPerformance         OUT_PERF
# coal                       True
# pesticides                False
# adult                     False
# percentile                84.13
# peerGroup                 Steel
# smallArms                 False
# environmentScore          16.32
# governancePercentile       None
# militaryContract          False

# %%
tata.recommendations

# %%
tata.calendar
# Out:
# Empty DataFrame
# Columns: []
# Index: [Earnings Date, Earnings Average, Earnings Low, Earnings High, Revenue Average, Revenue Low, Revenue High]

# %% [markdown]
# ### Company International Security Identification Number

# %%
tata.isin
# Out:
# 'TH0692010R12'

# %%
data = yf.download("AMZN AAPL GOOG", start="2021-01-01", end="2021-04-06")
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                                 Close               \
#                   AAPL         AMZN         GOOG        AAPL         AMZN
# Date
# 2020-12-31  132.492020  3256.929932  1751.880005  132.690002  3256.929932
# 2021-01-04  129.216919  3186.629883  1728.239990  129.410004  3186.629883
# 2021-01-05  130.814514  3218.510010  1740.920044  131.009995  3218.510010
# 2021-01-06  126.411102  3138.379883  1735.290039  126.599998  3138.379883
# 2021-01-07  130.724655  3162.159912  1787.250000  130.919998  3162.159912
# ...                ...          ...          ...         ...          ...
# 2021-03-29  121.389999  3075.729980  2055.949951  121.389999  3075.729980
# 2021-03-30  119.900002  3055.290039  2055.540039  119.900002  3055.290039
# 2021-03-31  122.150002  3094.080078  2068.629883  122.150002  3094.080078
# 2021-04-01  123.000000  3161.000000  2137.750000  123.000000  3161.000000
# ...

# %%
data = yf.download("AMZN AAPL GOOG", start="2021-01-01", end="2021-04-06",group_by='Ticker')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                    AMZN                                                      \
#                    Open         High          Low        Close    Adj Close
# Date
# 2020-12-31  3275.000000  3282.919922  3241.199951  3256.929932  3256.929932
# 2021-01-04  3270.000000  3272.000000  3144.020020  3186.629883  3186.629883
# 2021-01-05  3166.010010  3223.379883  3165.060059  3218.510010  3218.510010
# 2021-01-06  3146.479980  3197.510010  3131.159912  3138.379883  3138.379883
# 2021-01-07  3157.000000  3208.540039  3155.000000  3162.159912  3162.159912
# ...                 ...          ...          ...          ...          ...
# 2021-03-29  3055.439941  3091.250000  3028.449951  3075.729980  3075.729980
# 2021-03-30  3070.010010  3073.000000  3034.000000  3055.290039  3055.290039
# 2021-03-31  3064.060059  3119.330078  3062.500000  3094.080078  3094.080078
# ...

# %% [markdown]
# ### Price to Earning Ratio

# %%
tata.info['forwardPE']

# %% [markdown]
# ### Yearly Divident Rate

# %%
tata.info['dividendRate']
# Out:
# 10

# %%
import pandas as pd

tickers_list = ["aapl", "goog", "amzn", "BAC", "BA"] # example list
tickers_data= {} # empty dictionary

# %%
for ticker in tickers_list:
    ticker_object = yf.Ticker(ticker)

    #convert info() output from dictionary to dataframe
    temp = pd.DataFrame.from_dict(ticker_object.info, orient="index")
    temp.reset_index(inplace=True)
    temp.columns = ["Attribute", "Recent"]
    
    # add (ticker, dataframe) to main dictionary
    tickers_data[ticker] = temp

tickers_data
# Out:
# {'aapl':                     Attribute  \
#  0                         zip
#  1                      sector
#  2           fullTimeEmployees
#  3         longBusinessSummary
#  4                        city
#  ..                        ...
#  118  impliedSharesOutstanding
#  119                  category
#  120     fiveYearAverageReturn
#  121        regularMarketPrice
#  122                  logo_url
#
#                                                  Recent
#  0                                                95014
#  1                                           Technology
#  2                                               147000
#  3    Apple Inc. designs, manufactures, and markets ...
#  4                                            Cupertino
#  ..                                                 ...
#  118                                               None
#  119                                               None
#  120                                               None
# ...

# %%
combined_data = pd.concat(tickers_data)
combined_data = combined_data.reset_index()
combined_data
# Out:
#     level_0  level_1                 Attribute  \
# 0      aapl        0                       zip
# 1      aapl        1                    sector
# 2      aapl        2         fullTimeEmployees
# 3      aapl        3       longBusinessSummary
# 4      aapl        4                      city
# ..      ...      ...                       ...
# 610      BA      117  impliedSharesOutstanding
# 611      BA      118                  category
# 612      BA      119     fiveYearAverageReturn
# 613      BA      120        regularMarketPrice
# 614      BA      121                  logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               147000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# ...

# %%
del combined_data["level_1"] # clean up unnecessary column
combined_data.columns = ["Ticker", "Attribute", "Recent"] # update column names

combined_data
# Out:
#     Ticker                 Attribute  \
# 0     aapl                       zip
# 1     aapl                    sector
# 2     aapl         fullTimeEmployees
# 3     aapl       longBusinessSummary
# 4     aapl                      city
# ..     ...                       ...
# 610     BA  impliedSharesOutstanding
# 611     BA                  category
# 612     BA     fiveYearAverageReturn
# 613     BA        regularMarketPrice
# 614     BA                  logo_url
#
#                                                 Recent
# 0                                                95014
# 1                                           Technology
# 2                                               147000
# 3    Apple Inc. designs, manufactures, and markets ...
# 4                                            Cupertino
# ..                                                 ...
# 610                                               None
# 611                                               None
# ...

# %%
employees = combined_data[combined_data["Attribute"]=="fullTimeEmployees"].reset_index()
del employees["index"] # clean up unnecessary column

employees
# Out:
#   Ticker          Attribute   Recent
# 0   aapl  fullTimeEmployees   147000
# 1   goog  fullTimeEmployees   135301
# 2   amzn  fullTimeEmployees  1298000
# 3    BAC  fullTimeEmployees   213000
# 4     BA  fullTimeEmployees   141000

# %%
employees_sorted = employees.sort_values('Recent',ascending=False)
employees_sorted
# Out:
#   Ticker          Attribute   Recent
# 2   amzn  fullTimeEmployees  1298000
# 3    BAC  fullTimeEmployees   213000
# 0   aapl  fullTimeEmployees   147000
# 4     BA  fullTimeEmployees   141000
# 1   goog  fullTimeEmployees   135301

# %% [markdown]
# ## Market Capital

# %%
tata.info['marketCap']
# Out:
# 1001484451840

# %% [markdown]
# ## Adani Transmission Stock

# %%
adani=yf.Ticker('ADANITRANS.NS')

# %%
adani_info=adani.info
adani_info
# Out:
# {'zip': '382421',
#  'sector': 'Utilities',
#  'fullTimeEmployees': 5417,
#  'longBusinessSummary': 'Adani Transmission Limited, together with its subsidiaries, engages in the generation, transmission, and distribution of power in India. The company operates through Transmission, Trading, and Mumbai GTD Business segments. It builds, commissions, operates, and maintains electric power transmission systems; and distributes electricity in the suburbs of Mumbai. The company operates and maintains approximately 11,576 circuit kilometers of transmission lines with a total transformation capacity of 18,330 mega volt ampere in the states of Gujarat, Maharashtra, Rajasthan, Madhya Pradesh, Uttar Pradesh, Bihar, Jharkhand, Haryana, and Chhattisgarh. In addition, it engages in the trading of agri commodities. The company was incorporated in 2013 and is headquartered in Ahmedabad, India. Adani Transmission Limited is a subsidiary of S.B. Adani Family Trust.',
#  'city': 'Ahmedabad',
# ...

# %%
adani_info['country']
# Out:
# 'India'

# %%
adani_info['sector']
# Out:
# 'Utilities'

# %%
adani_stock_price=adani.history(start='2021-04-01',end='2021-04-07')

# %%
adani_stock_price.head()
# Out:
#               Open         High          Low        Close   Volume  Dividends  \
# Date
# 2021-04-01   923.0   999.200012   917.049988   999.200012  2213099          0
# 2021-04-05  1008.0  1099.099976  1000.000000  1095.150024  3267413          0
# 2021-04-06  1110.0  1144.699951  1100.000000  1110.650024  1910242          0
#
#             Stock Splits
# Date
# 2021-04-01             0
# 2021-04-05             0
# 2021-04-06             0

# %%
adani_stock_price.reset_index(inplace=True)
adani_stock_price.plot(x="Date",y='Open',title='Stock Open')
adani_stock_price.plot(x='Date',y='Close',title='Stock Close')
# Out:
# <AxesSubplot:title={'center':'Stock Close'}, xlabel='Date'>
